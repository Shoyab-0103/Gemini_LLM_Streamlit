# %%
from app import get_gemini_response
import json

prompt = "List 5 biriyanis in json format like this : [{Recipe : 'name', Ingredients : ['ingredient1', 'ingredient2'], Instructions : 'instructions'}]"
response = get_gemini_response(prompt)
print(response)

try:
    data = json.loads(response)
    print(json.dumps(data, indent=2))
except json.JSONDecodeError as e:
    print(f"Error parsing JSON: {e}")
    print("Raw response:", response)
# Out:
# ```json
# [
#   {
#     "Recipe": "Chicken Biryani",
#     "Ingredients": [
#       "Chicken",
#       "Basmati Rice",
#       "Onions",
#       "Tomatoes",
#       "Yogurt",
#       "Ginger-Garlic Paste",
#       "Biryani Masala",
#       "Mint Leaves",
#       "Coriander Leaves",
#       "Saffron"
#     ],
#     "Instructions": "Marinate chicken with yogurt and spices.  Sauté onions, tomatoes, and ginger-garlic paste. Layer parboiled rice and marinated chicken in a pot.  Garnish with mint, coriander, and saffron.  Cook on low heat until rice is done."
#   },
#   {
#     "Recipe": "Mutton Biryani",
#     "Ingredients": [
#       "Mutton",
#       "Basmati Rice",
#       "Onions",
#       "Tomatoes",
#       "Yogurt",
#       "Ginger-Garlic Paste",
#       "Biryani Masala",
#       "Mint Leaves",
#       "Coriander Leaves",
#       "Saffron"
#     ],
#     "Instructions": "Marinate mutton with yogurt and spices. Sauté onions, tomatoes, and ginger-garlic paste. Layer parboiled rice and marinated mutton in a pot. Garnish with mint, coriander, and saffron. Cook on low heat until rice and mutton are tender."
#   },
#   {
#     "Recipe": "Vegetable Biryani",
#     "Ingredients": [
#       "Mixed Vegetables (Carrots, Potatoes, Peas, Beans)",
#       "Basmati Rice",
#       "Onions",
#       "Tomatoes",
#       "Yogurt",
#       "Ginger-Garlic Paste",
#       "Biryani Masala",
#       "Mint Leaves",
#       "Coriander Leaves",
#       "Saffron"
#     ],
#     "Instructions": "Sauté onions, tomatoes, and ginger-garlic paste. Add mixed vegetables and spices. Layer parboiled rice and the vegetable mixture in a pot.  Garnish with mint, coriander, and saffron.  Cook on low heat until rice and vegetables are tender."
#   },
#   {
#     "Recipe": "Egg Biryani",
#     "Ingredients": [
#       "Eggs",
#       "Basmati Rice",
#       "Onions",
#       "Tomatoes",
#       "Ginger-Garlic Paste",
#       "Biryani Masala",
#       "Mint Leaves",
#       "Coriander Leaves",
#       "Green Chillies"
#     ],
#     "Instructions": "Boil and peel eggs.  Sauté onions, tomatoes, and ginger-garlic paste. Layer parboiled rice and boiled eggs in a pot.  Garnish with mint, coriander, and green chilies. Cook on low heat until rice is done."
#   },
#   {
#     "Recipe": "Fish Biryani",
#     "Ingredients": [
#       "Fish Fillets",
#       "Basmati Rice",
#       "Onions",
#       "Tomatoes",
#       "Yogurt",
#       "Ginger-Garlic Paste",
#       "Biryani Masala",
#       "Mint Leaves",
#       "Coriander Leaves",
#       "Coconut Milk"
#     ],
#     "Instructions": "Marinate fish with yogurt and spices. Sauté onions, tomatoes, and ginger-garlic paste.  Layer parboiled rice and marinated fish in a pot. Add coconut milk. Garnish with mint and coriander. Cook on low heat until rice and fish are cooked."
#   }
# ]
# ```
# Error parsing JSON: Expecting value: line 1 column 1 (char 0)
# Raw response: ```json
# [
#   {
#     "Recipe": "Chicken Biryani",
#     "Ingredients": [
#       "Chicken",
#       "Basmati Rice",
#       "Onions",
#       "Tomatoes",
#       "Yogurt",
#       "Ginger-Garlic Paste",
#       "Biryani Masala",
#       "Mint Leaves",
#       "Coriander Leaves",
#       "Saffron"
#     ],
#     "Instructions": "Marinate chicken with yogurt and spices.  Sauté onions, tomatoes, and ginger-garlic paste. Layer parboiled rice and marinated chicken in a pot.  Garnish with mint, coriander, and saffron.  Cook on low heat until rice is done."
#   },
#   {
#     "Recipe": "Mutton Biryani",
#     "Ingredients": [
#       "Mutton",
#       "Basmati Rice",
#       "Onions",
#       "Tomatoes",
#       "Yogurt",
#       "Ginger-Garlic Paste",
#       "Biryani Masala",
#       "Mint Leaves",
#       "Coriander Leaves",
#       "Saffron"
#     ],
#     "Instructions": "Marinate mutton with yogurt and spices. Sauté onions, tomatoes, and ginger-garlic paste. Layer parboiled rice and marinated mutton in a pot. Garnish with mint, coriander, and saffron. Cook on low heat until rice and mutton are tender."
#   },
#   {
#     "Recipe": "Vegetable Biryani",
#     "Ingredients": [
#       "Mixed Vegetables (Carrots, Potatoes, Peas, Beans)",
#       "Basmati Rice",
#       "Onions",
#       "Tomatoes",
#       "Yogurt",
#       "Ginger-Garlic Paste",
#       "Biryani Masala",
#       "Mint Leaves",
#       "Coriander Leaves",
#       "Saffron"
#     ],
#     "Instructions": "Sauté onions, tomatoes, and ginger-garlic paste. Add mixed vegetables and spices. Layer parboiled rice and the vegetable mixture in a pot.  Garnish with mint, coriander, and saffron.  Cook on low heat until rice and vegetables are tender."
#   },
#   {
#     "Recipe": "Egg Biryani",
#     "Ingredients": [
#       "Eggs",
#       "Basmati Rice",
#       "Onions",
#       "Tomatoes",
#       "Ginger-Garlic Paste",
#       "Biryani Masala",
#       "Mint Leaves",
#       "Coriander Leaves",
#       "Green Chillies"
#     ],
#     "Instructions": "Boil and peel eggs.  Sauté onions, tomatoes, and ginger-garlic paste. Layer parboiled rice and boiled eggs in a pot.  Garnish with mint, coriander, and green chilies. Cook on low heat until rice is done."
#   },
#   {
#     "Recipe": "Fish Biryani",
#     "Ingredients": [
#       "Fish Fillets",
#       "Basmati Rice",
#       "Onions",
#       "Tomatoes",
#       "Yogurt",
#       "Ginger-Garlic Paste",
#       "Biryani Masala",
#       "Mint Leaves",
#       "Coriander Leaves",
#       "Coconut Milk"
#     ],
#     "Instructions": "Marinate fish with yogurt and spices. Sauté onions, tomatoes, and ginger-garlic paste.  Layer parboiled rice and marinated fish in a pot. Add coconut milk. Garnish with mint and coriander. Cook on low heat until rice and fish are cooked."
#   }
# ]
# ```
